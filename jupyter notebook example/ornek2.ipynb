# %%
import pandas as pd

# %%
import os
os.chdir("C:/Users/Devrim/Desktop/Veri Bilimi ile örnek github/Job_Recommendation_Engine_master/Datasets")

# %%
df=pd.read_csv("Job_Titles.csv")
df
# Out:
#      Unnamed: 0                                 Job_titles
# 0             2                             Top Executives
# 1             4                           Chief Executives
# 2             6            General and Operations Managers
# 3             8                                Legislators
# 4            10        Advertising and Promotions Managers
# ..          ...                                        ...
# 685        1372    Pump Operators, Except Wellhead Pumpers
# 686        1374  Refuse and Recyclable Material Collectors
# 687        1376                 Mine Shuttle Car Operators
# 688        1378          Tank Car, Truck, and Ship Loaders
# 689        1380      Miscellaneous Material Moving Workers
#
# [690 rows x 2 columns]

# %%
df["Job_titles"].tolist()
# Out:
# ['Top Executives',
#  'Chief Executives',
#  'General and Operations Managers',
#  'Legislators',
#  'Advertising and Promotions Managers',
#  'Marketing and Sales Managers',
#  'Sales Managers',
#  'Public Relations and Fundraising Managers',
#  'Administrative Services Managers',
#  'Computer and Information Systems Managers',
#  'Financial Managers',
#  'Industrial Production Managers',
#  'Purchasing Managers',
#  'Transportation, Storage, and Distribution Managers',
#  'Compensation and Benefits Managers',
#  'Human Resources Managers',
#  'Training and Development Managers',
#  'Other Management Occupations',
#  'Farmers, Ranchers, and Other Agricultural Managers',
#  'Construction Managers',
#  'Education Administrators, Preschool and Childcare Center/Program',
#  'Education Administrators, Postsecondary',
#  'Architectural and Engineering Managers',
#  'Food Service Managers',
#  'Funeral Service Managers',
#  'Gaming Managers',
#  'Lodging Managers',
# ...

# %%
durum=df["Job_titles"].to_frame()
durum
# Out:
#                                     Job_titles
# 0                               Top Executives
# 1                             Chief Executives
# 2              General and Operations Managers
# 3                                  Legislators
# 4          Advertising and Promotions Managers
# ..                                         ...
# 685    Pump Operators, Except Wellhead Pumpers
# 686  Refuse and Recyclable Material Collectors
# 687                 Mine Shuttle Car Operators
# 688          Tank Car, Truck, and Ship Loaders
# 689      Miscellaneous Material Moving Workers
#
# [690 rows x 1 columns]

# %%
durum.to_csv("Job_titles.csv")

# %%
pd.read_csv("Job_titles.csv")
# Out:
#      Unnamed: 0                                 Job_titles
# 0             0                             Top Executives
# 1             1                           Chief Executives
# 2             2            General and Operations Managers
# 3             3                                Legislators
# 4             4        Advertising and Promotions Managers
# ..          ...                                        ...
# 685         685    Pump Operators, Except Wellhead Pumpers
# 686         686  Refuse and Recyclable Material Collectors
# 687         687                 Mine Shuttle Car Operators
# 688         688          Tank Car, Truck, and Ship Loaders
# 689         689      Miscellaneous Material Moving Workers
#
# [690 rows x 2 columns]

# %%
durum.to_csv("Job_titles.csv",index=False)

# %%
pd.read_csv("Job_titles.csv")
# Out:
#                                     Job_titles
# 0                               Top Executives
# 1                             Chief Executives
# 2              General and Operations Managers
# 3                                  Legislators
# 4          Advertising and Promotions Managers
# ..                                         ...
# 685    Pump Operators, Except Wellhead Pumpers
# 686  Refuse and Recyclable Material Collectors
# 687                 Mine Shuttle Car Operators
# 688          Tank Car, Truck, and Ship Loaders
# 689      Miscellaneous Material Moving Workers
#
# [690 rows x 1 columns]

# %%
os.chdir("C:/Users/Devrim/Desktop/Veri Bilimi ile örnek github/Job_Recommendation_Engine_master/Datasets")
pd.read_csv("best_jobs_in_america.csv")
# Out:
#     Rank                          Title
# 0      1  Mobile Applications Developer
# 1      2       Risk Management Director
# 2      3                        Landman
# 3      4                Product Analyst
# 4      5  Information Assurance Analyst
# ..   ...                            ...
# 95    96             Engagement Manager
# 96    97                 Civil Engineer
# 97    98         Occupational Therapist
# 98    99       User Experience Designer
# 99   100               Anesthesiologist
#
# [100 rows x 2 columns]

# %%
#pd.read_csv("best_jobs_in_america.csv",sheet_name=["96","116"]) sayfaları okumak için kullanılır devrim ozcay

# %%
a=pd.read_html("https://www.seismicportal.eu/fdsn-wsevent.html")
a
# Out:
# [                      Group                Parameter              Abbrevation  \
#  0          time constraints         time constraints         time constraints
#  1                       NaN                starttime                    start
#  2                       NaN                  endtime                      end
#  3   geographics constraints  geographics constraints  geographics constraints
#  4                       NaN     box area constraints     box area constraints
#  5                       NaN              minlatitude                   minlat
#  6                       NaN              maxlatitude                   maxlat
#  7                       NaN             minlongitude                   minlon
#  8                       NaN             maxlongitude                   maxlon
#  9                       NaN       circle constraints       circle constraints
#  10                      NaN                 latitude                      lat
# ...

# %%
a[0]
# Out:
#                       Group                Parameter              Abbrevation  \
# 0          time constraints         time constraints         time constraints
# 1                       NaN                starttime                    start
# 2                       NaN                  endtime                      end
# 3   geographics constraints  geographics constraints  geographics constraints
# 4                       NaN     box area constraints     box area constraints
# 5                       NaN              minlatitude                   minlat
# 6                       NaN              maxlatitude                   maxlat
# 7                       NaN             minlongitude                   minlon
# 8                       NaN             maxlongitude                   maxlon
# 9                       NaN       circle constraints       circle constraints
# 10                      NaN                 latitude                      lat
# ...
